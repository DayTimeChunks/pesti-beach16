# %% [markdown]
# ## Outlet Isotopes

# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 2016
# /Users/DayTightChunks/Documents/PhD/Models/phd-model-master/Analysis

# %%
PC = False
analysis = True
short_sim = True
version = "model_v12"
folder = "1"

timestamp = 'julian'

# %%
if analysis:
    dot = ''
else:
    dot = '..\\'
    
if PC:
    back = "\\"  
    sim_path = dot + version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# model_v12/

# %% [markdown]
# ## Observed

# %%
var = 'd13C'
obs = getOutletData("Delta_out", var, tss=True)

# Convert to NaN (if: 1e+09)
obs.loc[obs[var] > 0, var] = np.nan

# %%
if short_sim:
    s_obs = 166 - 1
    e_obs = 300
else:
    # Julian days
    s_obs = 0
    e_obs = 300

# Calendar days
if timestamp == 'julian':
    # Julian days
    x = obs.Jdays.tolist()[s_obs:e_obs]
else:
    # Calendar days
    dates = getTime(sep=";")
    x = dates.Date.tolist()[s_obs:e_obs]
    # dates = getTime(sep=";")
    # x = dates.Date.tolist()[s:e]

# %%
# Observed 'Conc (mu/L)'
# conc_obs[s_obs:(s_obs+20)]
qObs = obs[var].tolist()[s_obs:e_obs]

trace = go.Scatter(
        x = x,
        y = qObs,
        mode = 'lines',
        name = r'$\delta~13^{C}$',
        line = dict(
            color = 'green',
            width = 3,
            dash = 'dash')
)

# %% [markdown]
# ## Simulated

# %%
tss = ["outISO_d13C"]  # Concentration ug/L
    
names = [r'$\delta~13^{C} Sim.$']
palette = ['blue', 'purple', 'rgb(178,223,138)', '#F44336', '#3F51B5']

col = "sim"
data = []
data.append(trace)  # Append observed 
for i in range(len(tss)):  # Append simulated components
    filename = "resM_" + tss[i] + ".tss"
    sim_pd = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)
    
    sim = sim_pd.sim.tolist()
    trace = go.Scatter(
        x = x,
        y = sim,
        mode = 'lines',
        name = names[i],
        line = dict(
            color = palette[i],
            width = 3,
            dash = 'dot')
    )
    data.append(trace)


layout = go.Layout(
    title='Outlet',
    xaxis=dict(
        title='',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title=r'$\delta~13^{C} Sim.$',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

# %%
figname = "DeltaOutlet.png"

# %matplotlib inline
import plotlycred

newtab = True
online = False
if online:
    #fig = py.iplot(data) 
    fig = go.Figure(data=data, layout=layout)
    py.image.save_as(fig, filename=figname)
    # py.plot(fig, filename=figname) # Opens in web
else:
    fig = go.Figure(data=data, layout=layout)
    if newtab:
        plot(fig)
    else:
        iplot(fig)

# %% [markdown]
# ### Q Components $(m^3/d)$
#
# Follow this link to interact with the data:
#
# https://plot.ly/~DayTimeChunks/15/

# %%
from IPython.display import Image
if online:
    i = Image(figname)
    display(i)

# %% [markdown]
# ## Nash

# %%
start = 1
n_tests = 1
for i in range(start, n_tests+1):
    folder = str(i)
    col = 'Nash.c' + str(i)
    nash = pd.read_table(sim_path + folder + back + "resNash_q_m3.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)
    if i == 1:
        nash_all = nash
    else:
        nash_all = nash_all.merge(nash, left_on='Jdays', right_on='Jdays', how='outer')

if short_sim:
    ndata = nash_all[11:] # [10:] (v1)
else:
     ndata = nash_all[176:]

# %%
ndata.head()
# Out:
#     Jdays   Nash.c1
# 11    177  0.968443
# 12    178  0.960614
# 13    179  0.960501
# 14    180  0.962499
# 15    181  0.964306

# %%
nash = ndata['Nash.c1'].tolist()
x = ndata['Jdays'].tolist()

# %%
traceN = go.Scatter(
    x = x,
    y = nash,
    mode = 'lines',
    name = 'Nash.',
    line = dict(
        color = '#F44336',
        width = 3,
        dash = 'dot')
)
n = [traceN]
nfigname = "Nash.png"

# %matplotlib inline
import plotlycred

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=n)#, layout=layout)
    py.image.save_as(fig, filename=nfigname)
    # py.plot(fig, filename=figname) # Opens in web
else:
    fig = go.Figure(data=n)#, layout=layout)
    iplot(fig)
# Out:
# <div id="8f6813d9-d7d2-467c-a689-f72d8dd44003" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8f6813d9-d7d2-467c-a689-f72d8dd44003", [{"name": "Nash.", "mode": "lines", "y": [0.968443, 0.960614, 0.960501, 0.962499, 0.964306, 0.968374, 0.88535, 0.74922, 0.655936, 0.6389739999999999, 0.642228, 0.597385, 0.587129, 0.58691, 0.594763, 0.603008, 0.616101, 0.6221869999999999, 0.621576, 0.6243609999999999, 0.6296619999999999, 0.626642, 0.347724, 0.694735, 0.692527, 0.689846, 0.686149, 0.686004, 0.686852, 0.687906, 0.689392, 0.6886, 0.6852699999999999, 0.684136, 0.68213, 0.678879, 0.6749189999999999, 0.679246, 0.679246, 0.678975, 0.674377, 0.674287, 0.675345, 0.676966, 0.678838, 0.6816220000000001, 0.684603, 0.6293, 0.632664, 0.563923, 0.551774, 0.549983, 0.549416, 0.54967, 0.5502859999999999, 0.550822, 0.551164, 0.5514100000000001, 0.551068, 0.55156, 0.551981, 0.552369, 0.5529649999999999, 0.553582, 0.554257, 0.5347109999999999, 0.5738949999999999, 0.543543, 0.5354770000000001, 0.531175, 0.5305310000000001, 0.537569, 0.510881, 0.502306, 0.498112, 0.494385, 0.49232700000000007, 0.49092399999999997, 0.489417, 0.48812799999999995, 0.486966, 0.46403999999999995, 0.44983199999999995, 0.45851099999999995, 0.400187, 0.38340100000000005, 0.373971, 0.36967, 0.367265, 0.36596799999999996, 0.365184, 0.364728, 0.366755, 0.363532, 0.362009, 0.360754, 0.359996, 0.359308, 0.35880100000000004, 0.358541, 0.35875999999999997, 0.359039, 0.35951, 0.360218, 0.36098600000000003, 0.36182800000000004, 0.362695, 0.36357399999999995, 0.36451100000000003, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767, 0.365767], "x": [177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "line": {"dash": "dot", "width": 3, "color": "#F44336"}, "type": "scatter"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
