# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# /Users/DayTightChunks/Documents/PhD/Models/.nosync/pesti-beach16/Analysis

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
variable = "d13C"
figname = 'Soilsd13C.png'

# %% [markdown]
# ## Observed

# %%
n_obs = getSoilData("North", tss=True)
v_obs = getSoilData("Valley", tss=True)
s_obs = getSoilData("South", tss=True)
s_obs.head()
# Out:
#       DayMoYr        Date  Jdays   ID Transect  Wnum Date.Soil Date.ti  \
# 0  2015-10-01  01/10/2015      1  NaN      NaN   NaN       NaN     NaN
# 1  2015-10-02  02/10/2015      2  NaN      NaN   NaN       NaN     NaN
# 2  2015-10-03  03/10/2015      3  NaN      NaN   NaN       NaN     NaN
# 3  2015-10-04  04/10/2015      4  NaN      NaN   NaN       NaN     NaN
# 4  2015-10-05  05/10/2015      5  NaN      NaN   NaN       NaN     NaN
#
#    Conc.mug.g.dry.soil  Conc.ComSoil.SD  Mass.Soil.g  theta.prct  N_compsoil  \
# 0                  NaN              NaN          NaN         NaN         NaN
# 1                  NaN              NaN          NaN         NaN         NaN
# 2                  NaN              NaN          NaN         NaN         NaN
# 3                  NaN              NaN          NaN         NaN         NaN
# 4                  NaN              NaN          NaN         NaN         NaN
#
#    comp.d13C  comp.d13C.SD  N_isoComp  prctError  DD13C.comp  comp.IMP.d13C
# 0        NaN           NaN        NaN        NaN         NaN            NaN
# 1        NaN           NaN        NaN        NaN         NaN            NaN
# 2        NaN           NaN        NaN        NaN         NaN            NaN
# 3        NaN           NaN        NaN        NaN         NaN            NaN
# 4        NaN           NaN        NaN        NaN         NaN            NaN

# %%
if variable == "d13C":
    name = "comp.d13C"
nConc = n_obs[name].tolist()
vConc = v_obs[name].tolist()
sConc = s_obs[name].tolist()

# %% [markdown]
# ## Simulated

# %%
# Model version and mc-run number:
version = "v10"
folder = "1"

# Working computer
PC = False
if PC:
    back = "\\"  
    sim_path = version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# v10/

# %%
col = 'sim' # variable + '.North'
transect = 'nor'
name_tss = 'dC13'
filename = "resM_" + transect + name_tss + ".tss"

c_north_sim = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)

simN = c_north_sim[col].tolist()

# %%
transect = 'val'
name_tss = 'dC13'
filename = "resM_" + transect + name_tss + ".tss"
c_val_sim = pd.read_table(sim_path + folder + back + 
                          filename, 
                          skiprows=4, delim_whitespace=True,
                          names=['Jdays', col],
                          header=None)

simV = c_val_sim[col].tolist()

# %%
transect = 'sou'
name_tss = 'dC13'
filename = "resM_" + transect + name_tss + ".tss"
c_sou_sim = pd.read_table(sim_path + folder + back + 
                          filename, skiprows=4, delim_whitespace=True,
                          names=['Jdays', col],
                          header=None)

simS = c_sou_sim[col].tolist()

# %% [markdown]
# ## Plotting

# %%
# Julian days
x = s_obs.Jdays.tolist()

start = 180
end = 300

# %% [markdown]
# ### Observed

# %%
nObs = go.Scatter(
    x = x[start:end],
    y = nConc[start:end],
    mode = 'markers',
    name = 'North '  + variable,
    marker=dict(
        color= 'red', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

vObs = go.Scatter(
    x = x[start:end],
    y = vConc[start:end],
    mode = 'markers',
    name = 'Valley ' + variable,
    marker=dict(
        color= 'green', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

sObs = go.Scatter(
    x = x[start:end],
    y = sConc[start:end],
    mode = 'markers',
    name = 'South ' + variable,
    marker=dict(
        color= 'blue', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

# %% [markdown]
# ### Simulated

# %%
traceN = go.Scatter(
    x = x[start:end],
    y = simN[start:end],
    mode = 'lines',
    name = 'North Sim.',
    marker=dict(
        color= 'red')
)

traceV = go.Scatter(
    x = x[start:end],
    y = simV[start:end],
    mode = 'lines',
    name = 'Valley Sim.',
    marker=dict(
        color='green')
)

traceS = go.Scatter(
    x = x[start:end],
    y = simS[start:end],
    mode = 'lines',
    name = 'South Sim.',
    marker=dict(
        color= 'blue')
)

# %%
data = [nObs, vObs, sObs, traceN, traceV, traceS]

# %%
# %matplotlib inline
import plotlycred

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=data) # , layout=layout)
    py.image.save_as(fig, filename=figname)
else:
    iplot(data)
# Out:
# <div id="e501c6e7-180b-46a7-b177-ae32de402d87" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e501c6e7-180b-46a7-b177-ae32de402d87", [{"name": "North d13C", "marker": {"color": "red", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, -31.4, null, null, null, null, null, null, null, null, -31.2, null, null, null, -31.8333333333333, null, null, null, null, null, null, null, -31.766666666666698, null, null, null, null, null, null, -30.7, null, null, null, null, null, null, -29.4333333333333, null, null, null, null, null, null, null, null, null, null, null, null, null, -29.6, null, null, null, null, null, null, null, null, null, null, null, null, null, -29.8, null, null, null, null, null, null, -29.45, null, null, null, null, null, null, null, null, null, null, null, null, null, -29.5, null, null, null, null, null, -28.95, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "x": [181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "type": "scatter"}, {"name": "Valley d13C", "marker": {"color": "green", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, -29.966666666666697, null, null, null, null, null, null, null, null, -31.766666666666698, null, null, null, -31.1, null, null, null, null, null, null, null, -30.6333333333333, null, null, null, null, null, null, -29.8333333333333, null, null, null, null, null, null, -29.35, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, -30.5, null, null, null, null, null, null, -29.7, null, null, null, null, null, null, -29.9, null, null, null, null, null, null, -29.533333333333303, null, null, null, null, null, null, -29.6333333333333, null, null, null, null, null, -27.9, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "x": [181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "type": "scatter"}, {"name": "South d13C", "marker": {"color": "blue", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, -31.233333333333302, null, null, null, null, null, null, null, null, -31.0666666666667, null, null, null, -30.9333333333333, null, null, null, null, null, null, null, -30.6, null, null, null, null, null, null, -30.8, null, null, null, null, null, null, -31.0666666666667, null, null, null, null, null, null, -29.466666666666697, null, null, null, n ...

# %%
from IPython.display import Image
if online:
    i = Image(figname)
    display(i)
