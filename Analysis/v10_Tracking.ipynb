# %% [markdown]
# ## Pesticide Mass at cell level
#
#
# ### Samples at S11
#
# Current error in recording variable:
#
# - Conc = mass
# - Mass = conc

# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# /Users/DayTightChunks/Documents/PhD/Models/.nosync/pesti-beach16/Analysis

# %%
PC = False
version = "v10"
folder = "1"

# %%
if PC:
    back = "\\"  
    sim_path = version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# v10/

# %% [markdown]
# ## Contribution to:

# %%
name = "s11_test"

# %%
components = ["s11_smass", "s11_sconc"] 
pallete = ["#F44336", '#673AB7', '#3F51B5', '#009688', '#FF9800', '#4CAF50', '#03A9F4']
# red, purple, indigo, teal-green, orange, green, light-blue

# %%
# Simulated data
sim_list = []

# Time series name
col = 'sim'

for i in range(len(components)):
    name_tss = components[i]
    filename = "resM_" + name_tss + ".tss"
    sim = pd.read_table(sim_path + folder + back + filename, 
                                skiprows=4, delim_whitespace=True,
                                names=['Jdays', col],
                                header=None)
    sim_list.append(sim[col].tolist())

# %% [markdown]
# ## Plotting

# %%
# Julian days
# x = s_obs.Jdays.tolist()
dates = getTime(sep=";")
x = dates.Date.tolist()

start = 175
end = 300

# %%
# Add sim lines to data
data = []
for i in range(len(components)):
    pobj = go.Scatter(
        x = x[start:end],
        y = sim_list[i][start:end],
        mode = 'lines',
        name = components[i] + " Sim.",
        marker=dict(color=pallete[i]))
    data.append(pobj)

# %%
# Layout
layout = go.Layout(
    title='Samples Points S11',
    xaxis=dict(
        title='',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title=r'$S-met$',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

# %%
# %matplotlib inline
import plotlycred
figname = name + '.png'

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=data, layout=layout)
    py.image.save_as(fig, filename=figname)
else:
    iplot(data)
# Out:
# <div id="8591c154-6d49-4d03-ad75-03505a67a087" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8591c154-6d49-4d03-ad75-03505a67a087", [{"name": "s11_smass Sim.", "marker": {"color": "#F44336"}, "mode": "lines", "y": [6.0465600000000005e-19, 6.0465600000000005e-19, 6.0465600000000005e-19, 6.0465600000000005e-19, 6.0465600000000005e-19, 6.0465600000000005e-19, 6.080100000000001e-19, 6.11376e-19, 4.18191, 3.4072199999999997, 3.24513, 3.24513, 3.46076, 3.51795, 3.5089300000000003, 3.32747, 3.24791, 3.08334, 3.15035, 3.30419, 3.17549, 3.26263, 3.3345, 3.3345, 3.3345, 3.3345, 3.3345, 3.51802, 3.21278, 3.2307799999999998, 3.4227800000000004, 3.07524, 2.95146, 2.15881, 2.15881, 2.15881, 2.15881, 2.15881, 2.2631799999999997, 2.3005, 2.31313, 2.44658, 0.44536099999999995, 0.466958, 0.469583, 0.488414, 0.4491
# ...

# %%
from IPython.display import Image
if online:
    i = Image(figname)
    display(i)
