# %% [markdown]
# ## Hydrology
#
#
# ### Contribution to discharge
#
# - discharge (obs vs sim)
# - base flow
# - lateral flow
# - runoff
# - drainage

# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go
init_notebook_mode(connected=True)

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# 2016
# D:\Documents\these_pablo\Models\BEACH2016\Analysis

# %%
PC = True
version = "model_v11"
folder = "1"
short_sim = True

# %%
if PC:
    back = "\\"  
    sim_path = "..\\" + version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# ..\model_v11\

# %% [markdown]
# ### Observed

# %%
# Q (m3)
q_obs = getWaterData(tss=True)
q_obs.loc[q_obs.Qm3 < 0,'Qm3'] = np.nan

# Q sim
col = "sim"
name_tss = "tot_accVol_m3"

filename = "resW_" + name_tss + ".tss"

q_sim_m3 = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)

# Components
# Baseflow (m3)
if False:
    name_tss = "accBaseflow_m3"
    filename = "resW_" + name_tss + ".tss"

    bf_m3 = pd.read_table(sim_path + folder + back + filename, 
                                skiprows=4, delim_whitespace=True,
                                names=['Jdays', col],
                                header=None)

# Outlet latflow (m3)
name_tss = "o_cellLatflow_m3"
filename = "resW_" + name_tss + ".tss"

lf_m3 = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)

# Runoff (m3)
name_tss = "accRunoff_m3"
filename = "resW_" + name_tss + ".tss"

ro_m3 = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)

# Drainage (m3)
name_tss = "o_accDrain_m3"
filename = "resW_" + name_tss + ".tss"

dr_m3 = pd.read_table(sim_path + folder + back + filename, 
                            skiprows=4, delim_whitespace=True,
                            names=['Jdays', col],
                            header=None)

# %%
dr_m3.head()
# Out:
#    Jdays       sim
# 0    166  1.043460
# 1    167  0.103674
# 2    168  0.009866
# 3    169  0.000656
# 4    170  0.000425

# %%
# Observations 
if short_sim:
    s_obs = 166 - 1
    e_obs = 300
else:
    # Julian days
    s_obs = 0
    e_obs = 300
    
q_obs[s_obs:(s_obs+20)]
# Out:
#      Jdays      Qm3
# 165    166      NaN
# 166    167      NaN
# 167    168      NaN
# 168    169      NaN
# 169    170      NaN
# 170    171      NaN
# 171    172      NaN
# 172    173      NaN
# 173    174      NaN
# 174    175      NaN
# 175    176      NaN
# 176    177   42.939
# 177    178   28.655
# 178    179   28.440
# 179    180   30.559
# 180    181   29.590
# 181    182   46.096
# 182    183  486.588
# 183    184  373.460
# 184    185  298.174

# %%
jdays = dr_m3['Jdays']
qObs = q_obs.Qm3.tolist()[s_obs:e_obs]

# %%
# Julian days (simulations)
s = 166
e = 300

# Calendar days
dates = getTime(sep=";")
# x = dates.Date.tolist()[s:e]

# Julian days
x = jdays.tolist()

# if short_sim:
#     qSim = q_sim_m3.sim.tolist()[s:e]
# #     bf = bf_m3.sim.tolist()[s:e]
#     lf = lf_m3.sim.tolist()[s:e]
#     ro = ro_m3.sim.tolist()[s:e]
#     dr = dr_m3.sim.tolist()[s:e]
# else:

qSim = q_sim_m3.sim.tolist()
#     bf = bf_m3.sim.tolist()
lf = lf_m3.sim.tolist()
ro = ro_m3.sim.tolist()
dr = dr_m3.sim.tolist()

# %%
traceObs = go.Scatter(
    x = x,
    y = qObs,
    mode = 'lines',
    name = 'Q (m3/d)',
    marker=dict(
        color= 'green')
)

traceSim = go.Scatter(
    x = x,
    y = qSim,
    mode = 'lines',
    name = 'Q Sim.',
    marker=dict(
        color= 'blue')
)
if False:
    traceBF = go.Scatter(
        x = x,
        y = bf,
        mode = 'lines',
        name = 'Baseflow Sim.',
        line = dict(
            color = '#FFBAD2',
            width = 3,
            dash = 'dot')
    )

traceLF = go.Scatter(
    x = x,
    y = lf,
    mode = 'lines',
    name = 'Latflow Sim.',
    line = dict(
        color = 'purple',
        width = 3,
        dash = 'dot')
)

traceRO = go.Scatter(
    x = x,
    y = ro,
    mode = 'lines',
    name = 'Runoff Sim.',
    line = dict(
        color = 'rgb(178,223,138)',
        width = 3,
        dash = 'dot')
)

traceDR = go.Scatter(
    x = x,
    y = dr,
    mode = 'lines',
    name = 'Drainage Sim.',
    line = dict(
        color = '#F44336',
        width = 3,
        dash = 'dot')
)

layout = go.Layout(
    title='Discharge Components',
    xaxis=dict(
        title='',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        
"x": [166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 18 ...

# %% [markdown]
# ### Q Components $(m^3/d)$
#
# Follow this link to interact with the data:
#
# https://plot.ly/~DayTimeChunks/15/

# %%
from IPython.display import Image
if online:
    i = Image(figname)
    display(i)

# %%
start = 1
n_tests = 1
for i in range(start, n_tests+1):
    folder = str(i)
    col = 'Nash.c' + str(i)
    nash = pd.read_table(sim_path + folder + back + "resNash_q_m3.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)
    if i == 1:
        nash_all = nash
    else:
        nash_all = nash_all.merge(nash, left_on='Jdays', right_on='Jdays', how='outer')

ndata = nash_all[11:] # [10:] (v1)

# %%
ndata.head()
# Out:
#     Jdays   Nash.c1
# 11    177  0.989031
# 12    178  0.993065
# 13    179  0.995002
# 14    180  0.995723
# 15    181  0.996587

# %%
nash = ndata['Nash.c1'].tolist()

# %%
traceN = go.Scatter(
    x = x,
    y = nash,
    mode = 'lines',
    name = 'Nash.',
    line = dict(
        color = '#F44336',
        width = 3,
        dash = 'dot')
)
n = [traceN]
nfigname = "Nash.png"

# %matplotlib inline
import plotlycred

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=n)#, layout=layout)
    py.image.save_as(fig, filename=nfigname)
    # py.plot(fig, filename=figname) # Opens in web
else:
    fig = go.Figure(data=n)#, layout=layout)
    iplot(fig)
# Out:
# <div id="be65d695-750a-4fff-8b2a-09f7a715f816" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be65d695-750a-4fff-8b2a-09f7a715f816", [{"name": "Nash.", "mode": "lines", "y": [0.989031, 0.993065, 0.995002, 0.9957229999999999, 0.9965870000000001, 0.9948950000000001, 0.9185399999999999, 0.899749, 0.832966, 0.802325, 0.7873859999999999, 0.70614, 0.686184, 0.642861, 0.622442, 0.601074, 0.5936170000000001, 0.578688, 0.558485, 0.5499069999999999, 0.545603, 0.532568, 0.236502, 0.599873, 0.605791, 0.599849, 0.597313, 0.595303, 0.590495, 0.587022, 0.585533, 0.580813, 0.573427, 0.571084, 0.567125, 0.562128, 0.556664, 0.561891, 0.561891, 0.559137, 0.560397, 0.561246, 0.558254, 0.557281, 0.557465, 0.559906, 0.563103, 0.490404, 0.552747, 0.522386, 0.500605, 0.495041, 0.492649, 0.49211099999999997, 0.492358, 0.492522, 0.492521, 0.492516, 0.491911, 0.492716, 0.493129, 0.49354499999999996, 0.49422299999999997, 0.494946, 0.495745, 0.46358299999999997, 0.5081, 0.47491099999999997, 0.46499700000000005, 0.45990699999999995, 0.46564099999999997, 0.46550600000000003, 0.433054, 0.42140900000000003, 0.415616, 0.412602, 0.40996000000000005, 0.408304, 0.40667, 0.40667, 0.405951, 0.401215, 0.387548, 0.40291, 0.347441, 0.334889, 0.32548499999999997, 0.32122, 0.318869, 0.317656, 0.31697, 0.316619, 0.316011, 0.312945, 0.31154499999999996, 0.31042600000000004, 0.309798, 0.309244, 0.30887, 0.308738, 0.309076, 0.309473, 0.31005900000000003, 0.310879, 0.311758, 0.31271, 0.313686, 0.31467399999999995, 0.31383099999999997, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003, 0.31519400000000003], "x": [166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "line": {"dash": "dot", "width": 3, "color": "#F44336"}, "type": "scatter"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
