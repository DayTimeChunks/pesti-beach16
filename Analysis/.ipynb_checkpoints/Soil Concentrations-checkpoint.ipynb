# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# /Users/DayTightChunks/Documents/PhD/Models/.nosync/pesti-beach16/Analysis

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ## Observed

# %%
n_obs = getSoilData("North", tss=True)
v_obs = getSoilData("Valley", tss=True)
s_obs = getSoilData("South", tss=True)
# s_obs.head()

nConc = n_obs['Conc.mug.g.dry.soil'].tolist()
vConc = v_obs['Conc.mug.g.dry.soil'].tolist()
sConc = s_obs['Conc.mug.g.dry.soil'].tolist()

# %% [markdown]
# ## Simulated

# %%
# Model version and mc-run number:
version = "v9"
folder = "1"

# Working computer
PC = False
if PC:
    back = "\\"  
    sim_path = version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# v9/

# %%
col = 'Conc.North'
c_north_sim = pd.read_table(sim_path + folder + back + "resM_norCONC.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)

simN = c_north_sim['Conc.North'].tolist()

# %%
col = 'Conc.Valley'
c_val_sim = pd.read_table(sim_path + folder + back + "resM_valCONC.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)

simV = c_val_sim['Conc.Valley'].tolist()

# %%
col = 'Conc.South'
c_sou_sim = pd.read_table(sim_path + folder + back + "resM_souCONC.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)

simS = c_sou_sim['Conc.South'].tolist()

# %% [markdown]
# ## Plotting

# %%
# Julian days
x = s_obs.Jdays.tolist()

start = 169
end = 300

# %% [markdown]
# ### Observed

# %%
nObs = go.Scatter(
    x = x[start:end],
    y = nConc[start:end],
    mode = 'markers',
    name = 'North Conc.',
    marker=dict(
        color= 'red', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

vObs = go.Scatter(
    x = x[start:end],
    y = vConc[start:end],
    mode = 'markers',
    name = 'Valley Conc.',
    marker=dict(
        color= 'green', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

sObs = go.Scatter(
    x = x[start:end],
    y = sConc[start:end],
    mode = 'markers',
    name = 'South Conc.',
    marker=dict(
        color= 'blue', # 'rgba(204, 204, 204, 0.95)',
        line=dict(
            color= 'black', #'rgba(217, 217, 217, 1.0)',
            width=1,
        ),
        symbol='circle',
        size=10)
)

# %% [markdown]
# ### Simulated

# %%
traceN = go.Scatter(
    x = x[start:end],
    y = simN[start:end],
    mode = 'lines',
    name = 'North Sim.',
    marker=dict(
        color= 'red')
)

traceV = go.Scatter(
    x = x[start:end],
    y = simV[start:end],
    mode = 'lines',
    name = 'Valley Sim.',
    marker=dict(
        color='green')
)

traceS = go.Scatter(
    x = x[start:end],
    y = simS[start:end],
    mode = 'lines',
    name = 'South Sim.',
    marker=dict(
        color= 'blue')
)

# %%
data = [nObs, vObs, sObs, traceN, traceV, traceS]

iplot(data)
# Out:
# <div id="09b0afaa-64a1-4472-b5de-e08940833b7d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("09b0afaa-64a1-4472-b5de-e08940833b7d", [{"name": "North Conc.", "marker": {"color": "red", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, 0.068592974, null, null, null, null, 1.037558485, null, null, null, null, null, 1.8544809869999999, null, null, null, null, null, null, null, null, 5.628514952000001, null, null, null, 7.183662148, null, null, null, null, null, null, null, 4.2233451330000005, null, null, null, null, null, null, 1.248904411, null, null, null, null, null, null, 1.285325524, null, null, null, null, null, null, 1.7504548119999999, null, null, null, null, null, null, 1.183860904, null, null, null, null, null, null, 1.001734733, null, null, null, null, null, null, 1.866402862, null, null, null, null, null, null, 1.300052437, null, null, null, null, null, null, 0.539267143, null, null, null, null, null, null, 0.35651763799999997, null, null, null, null, null, 0.8117856390000001, null, null, null, null, null, null, null, 1.115823402, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "x": [170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "type": "scatter"}, {"name": "Valley Conc.", "marker": {"color": "green", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, 0.043806464, null, null, null, null, 0.934229335, null, null, null, null, null, 1.7071507769999998, null, null, null, null, null, null, null, null, 3.518030954, null, null, null, 5.093894891000001, null, null, null, null, null, null, null, 4.697419678999999, null, null, null, null, null, null, 1.942645207, null, null, null, null, null, null, 2.128457231, null, null, null, null, null, null, 0.794915258, null, null, null, null, null, null, 0.726180171, null, null, null, null, null, null, 2.231496296, null, null, null, null, null, null, 2.589412953, null, null, null, null, null, null, 2.912150122, null, null, null, null, null, null, 3.193455428, null, null, null, null, null, null, 2.556143693, null, null, null, null, null, 1.851324451, null, null, null, null, null, null, null, 1.5305562519999998, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "x": [170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300], "type": "scatter"}, {"name": "South Conc.", "marker": {"color": "blue", "symbol": "circle", "line": {"color": "black", "width": 1}, "size": 10}, "mode" ...
