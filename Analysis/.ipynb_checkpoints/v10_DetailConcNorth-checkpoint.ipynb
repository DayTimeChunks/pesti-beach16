# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# /Users/DayTightChunks/Documents/PhD/Models/.nosync/pesti-beach16/Analysis

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
variable = "CONC"
det_name = "ug.g"
transect = 'North'

# %% [markdown]
# ## Observed

# %% [markdown]
# ### Detailed

# %%
detailed = ["n1", "n2", "n3", "n4", "n5", "n7", "n8"]
pallete = ["#F44336", '#673AB7', '#3F51B5', '#009688', '#FF9800', '#4CAF50', '#03A9F4']
# red, purple, indigo, teal-green, orange, green, light-blue

obs_list = []
for i in range(len(detailed)):
    name = detailed[i] + ".tss"
    o = getDetailed(name)
    o = o[det_name].tolist()
    obs_list.append(o)

# %% [markdown]
# ## Simulated

# %%
# Model version and mc-run number:
version = "v10"
folder = "1"

# Working computer
PC = False
if PC:
    back = "\\"  
    sim_path = version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# v10/

# %%
# Time series name
col = 'sim'
sim_list = []
for i in range(len(detailed)):
    name_tss = detailed[i] + variable
    filename = "resM_" + name_tss + ".tss"
    sim = pd.read_table(sim_path + folder + back + filename, 
                                skiprows=4, delim_whitespace=True,
                                names=['Jdays', col],
                                header=None)
    sim_list.append(sim[col].tolist())

# %% [markdown]
# ## Plotting

# %%
# Julian days
# x = s_obs.Jdays.tolist()
dates = getTime(sep=";")
x = dates.Date.tolist()

start = 175
end = 300

# %% [markdown]
# ### Observed (markers)

# %%
# Add markers to data
data = []
for i in range(len(detailed)):
    
    
    obs = go.Scatter(
        x = x[start:end],
        y = obs_list[i][start:end],
        mode = 'markers',
        name = detailed[i],
        marker=dict(
            color= pallete[i],
            line=dict(
                color= 'black', #'rgba(217, 217, 217, 1.0)',
                width=1,
            ),
            symbol='star',
            size=10)
    )
    data.append(obs)

# %% [markdown]
# ### Simulated

# %%
# Add sim lines to data
for i in range(len(detailed)):
    if detailed[i][0] == "n":
        color = 'red'
    elif detailed[i][0] == "t":
        color = 'green'
    else:
        color = 'blue'
    pobj = go.Scatter(
        x = x[start:end],
        y = sim_list[i][start:end],
        mode = 'lines',
        name = detailed[i] + " Sim.",
        marker=dict(color=pallete[i]))
    data.append(pobj)

# %%
# %matplotlib inline
import plotlycred
figname = transect + variable + 'D3.png'

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=data) # , layout=layout)
    py.image.save_as(fig, filename=figname)
else:
    iplot(data)
# Out:
# <div id="da136287-5ef0-4777-90bc-eff4d6043a62" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("da136287-5ef0-4777-90bc-eff4d6043a62", [{"name": "n1", "marker": {"color": "#F44336", "symbol": "star", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, 0.071209308, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null,