# %%
import datetime
import os

from obs_data import * 
from plotFunctions import *
import mpld3
mpld3.enable_notebook()

import seaborn as sns
sns.set_context(rc={'lines.markeredgewidth': 0.1})
sns.set(style="whitegrid")

# Plot graphs within this document
# %matplotlib inline

print(os.getcwd())

PC = True
# Out:
# D:\Documents\these_pablo\Models\BEACH2016\Analysis

# %% [markdown]
# ### Model version to inspect

# %%
version = "v5"

# %%
if PC:
    back = "\\"  
    path = version + back  
else:
    back = "/"
    path = version + back
    
print(path)
# simQ = pd.read_table(path + "res_accuVol_m3.tss", skiprows=4, delim_whitespace=True, names=['dt', 'Q_sim.m3'],
#                          header=None)
# Out:
# v5\

# %% [markdown]
# ### Nash comparisons

# %%
start = 1
n_tests = 11
for i in range(start, n_tests+1):
    folder = str(i)
    col = 'Nash.c' + str(i)
    nash = pd.read_table(path + folder + back + "res_nash_q_m3.tss", skiprows=4, delim_whitespace=True,
                         names=['Jdays', col],
                         header=None)
    if i == 1:
        nash_all = nash
    else:
        nash_all = nash_all.merge(nash, left_on='Jdays', right_on='Jdays', how='outer')

data = nash_all[200:]

# %%
data.head()
# Out:
#      Jdays   Nash.c1   Nash.c2   Nash.c3   Nash.c4   Nash.c5   Nash.c6  \
# 200    201  0.828933  0.763387  0.828945  0.653897  0.729930  0.828939
# 201    202  0.828352  0.752288  0.826326  0.640240  0.724924  0.828360
# 202    203  0.821079  0.738509  0.825201  0.629386  0.721123  0.821088
# 203    204  0.811587  0.729305  0.816302  0.620562  0.711994  0.811596
# 204    205  0.800695  0.718640  0.805399  0.610198  0.701385  0.800704
#
#       Nash.c7   Nash.c8   Nash.c9  Nash.c10  Nash.c11
# 200  0.828926  0.814238  0.779163  0.824206  0.832695
# 201  0.828343  0.814206  0.776435  0.822852  0.832625
# 202  0.821066  0.807909  0.767597  0.814310  0.826750
# 203  0.811574  0.798463  0.758293  0.804843  0.817239
# 204  0.800681  0.787608  0.747550  0.793970  0.806331

# %% [markdown]
# ### Nash models 1 - 5

# %%
start = 1
n_tests = 6

fig, ax1 = plt.subplots()
time = data.iloc[:, 0]
legend = []

for i in range(start, n_tests):
    l = "N" + str(i)
    legend.append(l)
for i in range(1, n_tests):
    ax1.plot(time, data.iloc[:, i], label=legend[i-start])
ylabel = 'Nash'
ax1.set_xlabel('Time (days)')
ax1.set_ylabel(ylabel)
plt.legend(loc='upper right', bbox_to_anchor=(1., 1), ncol=4, shadow=True, fancybox=True)
plt.show()

# %% [markdown]
# ### Nash models 6 - 11

# %%
start = 6
n_tests = 11

fig, ax1 = plt.subplots()
time = data.iloc[:, 0]
legend = []

for i in range(start, n_tests+1):
    l = "N" + str(i)
    legend.append(l)
for i in range(start, n_tests+1):
    ax1.plot(time, data.iloc[:, i], label=legend[i-start])
ylabel = 'Nash'
ax1.set_xlabel('Time (days)')
ax1.set_ylabel(ylabel)
plt.legend(loc='upper right', bbox_to_anchor=(1., 1), ncol=4, shadow=True, fancybox=True)
plt.show()

# %% [markdown]
# ## Plotting discharge

# %% [markdown]
# Base model:
# - c1 = 0.25
# - drain_coef = 0.8
# - z0 = 10 mm
#
# Best combinations:
# - Sc.4: c1 -= 0.15
# - Sc.2: drain_coef += 0.15
# - Sc.8: z0 x= 1.15
# - Sc.10: s1 += 0.15
#
# **Decreases** in lateral flow and **increases** in percolation potential improve nash coefficients.

# %%
"""
Import simulated data 
Observations are already imported above.
"""
# Edit observations (select relevant columns)
obs['DayMoYr'] = pd.to_datetime(obs['DayMoYr'])  # Convert to Date object
obs = obs[['DayMoYr', 'Jdays', 'VolTot.L']]  # keep desired columns

# Simulated Start time
yy = 2015
mm = 10
dd = 1
dt = datetime.date(yy, mm, dd)

folder = "4"
# print(path)
simQ = pd.read_table(path + folder + back + "res_accuVol_m3.tss", skiprows=4, delim_whitespace=True, names=['dt', 'Volm3'],
                         header=None)
# Out:
# v5\

# %%
simQ.head()
# Out:
#    dt     Volm3
# 0   1  188.3070
# 1   2   74.1338
# 2   3  257.7840
# 3   4   18.2090
# 4   5   99.2720

# %%
obs.dtypes
# basic_plot(obs)

# %%
fig, ax1 = plt.subplots()

obs['DayMoYr'] = pd.to_datetime(obs['DayMoYr'])
time = obs['DayMoYr']
obs_vol = obs['VolTot.L']
sim_vol = obs_vol*.10


legend = ["m3 observed", "m3 simulated"]
color_sequence = ['#d62728',
                  'darkviolet'
                  '#2ca02c',
                  '#1f77b4'
                  ]

ax1.plot(time, obs_vol) #, linestyle='dashdot', label=legend[0])
ax1.plot(time, sim_vol) #, linestyle='dashed', label=legend[1])

# add_margin(ax1, x=0.01, y=0.01)

ax1.set_xlabel('Time (days)')
ax1.set_ylabel('Volume (m3)')
plt.show()
