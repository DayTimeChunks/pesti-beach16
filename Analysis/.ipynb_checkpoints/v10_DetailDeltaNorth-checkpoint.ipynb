# %%
import datetime
import os

import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objs as go

import numpy as np

from obs_data import *

print(os.getcwd())
# Out:
# D:\Documents\these_pablo\Models\BEACH2016\Analysis

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
variable = "d13C"
det_name = "det.d13C"
transect = 'North'

# %% [markdown]
# ## Observed

# %% [markdown]
# ### Detailed

# %%
detailed = ["n1", "n2", "n3", "n4", "n5", "n7", "n8"]
pallete = ["#F44336", '#673AB7', '#3F51B5', '#009688', '#FF9800', '#4CAF50', '#03A9F4']
# red, purple, indigo, teal-green, orange, green, light-blue

obs_list = []
for i in range(len(detailed)):
    name = detailed[i] + ".tss"
    o = getDetailed(name)
    o = o[det_name].tolist()
    obs_list.append(o)

# %% [markdown]
# ## Simulated

# %%
# Model version and mc-run number:
version = "v10mo"
folder = "1"

# Working computer
PC = True
if PC:
    back = "\\"  
    sim_path = version + back  
else:
    back = "/"
    sim_path = version + back
    
print(sim_path)
# Out:
# v10mo\

# %%
# Time series name
col = 'sim'
sim_list = []
for i in range(len(detailed)):
    name_tss = detailed[i] + variable
    filename = "resM_" + name_tss + ".tss"
    sim = pd.read_table(sim_path + folder + back + filename, 
                                skiprows=4, delim_whitespace=True,
                                names=['Jdays', col],
                                header=None)
    sim_list.append(sim[col].tolist())

# %% [markdown]
# ## Plotting

# %%
# Julian days
# x = s_obs.Jdays.tolist()
dates = getTime(sep=";")
x = dates.Date.tolist()

start = 1
end = 300

# %% [markdown]
# ### Observed (markers)

# %%
# Add markers to data
data = []
for i in range(len(detailed)):
    
    
    obs = go.Scatter(
        x = x[start:end],
        y = obs_list[i][start:end],
        mode = 'markers',
        name = detailed[i],
        marker=dict(
            color= pallete[i],
            line=dict(
                color= 'black', #'rgba(217, 217, 217, 1.0)',
                width=1,
            ),
            symbol='star',
            size=10)
    )
    data.append(obs)

# %% [markdown]
# ### Simulated

# %%
# Add sim lines to data
for i in range(len(detailed)):
    if detailed[i][0] == "n":
        color = 'red'
    elif detailed[i][0] == "t":
        color = 'green'
    else:
        color = 'blue'
    pobj = go.Scatter(
        x = x[start:end],
        y = sim_list[i][start:end],
        mode = 'lines',
        name = detailed[i] + " Sim.",
        marker=dict(color=pallete[i]))
    data.append(pobj)

# %%
# %matplotlib inline
import plotlycred
figname = transect + variable + 'D3.png'

online = False
if online:
    # fig = py.iplot(data) 
    fig = go.Figure(data=data) # , layout=layout)
    py.image.save_as(fig, filename=figname)
else:
    iplot(data)
# Out:
# <div id="337b79ae-284e-4d7b-83b0-3320012b8bda" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("337b79ae-284e-4d7b-83b0-3320012b8bda", [{"name": "n1", "marker": {"color": "#F44336", "symbol": "star", "line": {"color": "black", "width": 1}, "size": 10}, "mode": "markers", "y": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], "x": ["02/10/2015", "03/10/2015", "04/10/2015", "05/10/2015", "06/10/2015", "07/10/2015", "08/10/2015", "09/10/2015", "10/10/2015", "11/10/2015", "12/10/2015", "13/10/2015", "14/10/2015", "15/10/2015", "16/10/2015", "17/10/2015", "18/10/2015", "19/10/2015", "20/10/2015", "21/10/2015", "22/10/2015", "23/10/2015", "24/10/2015", "25/10/2015", "26/10/2015", "27/10/2015", "28/10/2015", "29/10/2015", "30/10/2015", "31/10/2015", "01/11/2015", "02/11/2015", "03/11/2015", "04/11/2015", "05/11/2015", "06/11/2015", "07/11/2015", "08/11/2015", "09/11/2015", "10/11/2015", "11/11/2015", "12/11/2015", "13/11/2015", "14/11/2015", "15/11/2015", "16/11/2015", "17/11/2015", "18/11/2015", "19/11/2015", "20/11/2015", "21/11/2015", "22/11/2015", "23/11/2015", "24/11/2015", "25/11/2015", "26/11/2015", "27/11/2015", "28/11/2015", "29/11/2015", "30/11/2015", "01/12/2015", "02/12/2015", "03/12/2015", "04/12/2015", "05/12/2015", "06/12/2015", "07/12/2015", "08/12/2015", "09/12/2015", "10/12/2015", "11/12/2015", "12/12/2015", "13/12/2015", "14/12/2015", "15/12/2015", "16/12/2015", "17/12/2015", "18/12/2015", "19/12/2015", "20/12/2015", "21/12/2015", "22/12/2015", "23/12/2015", "24/12/2015", "25/12/2015", "26/12/2015", "27/12/2015", "28/12/2015", "29/12/2015", "30/12/2015", "31/12/2015", "01/01/2016", "02/01/2016", "03/01/2016", "04/01/2016", "05/01/2016", "06/01/2016", "07/01/2016", "08/01/2016", "09/01/2016", "10/01/2016", "11/01/2016", "12/01/2016", "13/01/2016", "14/01/2016", "15/01/2016", "16/01/2016", "17/01/2016", "18/01/2016", "19/01/2016", "20/01/2016", "21/01/2016", "22/01/2016", "23/01/2016", "24/01/2016", "25/01/2016", "26/01/2016", "27/01/2016", "28/01/2016", "29/01/2016", "30/01/2016", "31/01/2016", "01/02/2016", "02/02/2016 ...

# %% [markdown]
# Link:
#
# https://plot.ly/~DayTimeChunks/29/

# %%
from IPython.display import Image
if online:
    i = Image(figname)
    display(i)
